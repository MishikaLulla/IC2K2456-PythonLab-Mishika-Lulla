# %%
#square pattern
n = int(input("enter number of rows"))
for i in range(n):
    for j in range(n):
        print("*", end="")
    print()
# Out:
# enter number of rows 4
# ****
# ****
# ****
# ****
