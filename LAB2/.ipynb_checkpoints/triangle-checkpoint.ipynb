# %%
#triangle pattern
n = int(input("enter number of rows"))
for i in range(1, n + 1):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# enter number of rows 4
# *
# **
# ***
# ****
