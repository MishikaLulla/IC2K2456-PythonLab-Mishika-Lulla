# %%
#program6- this program prints a simple receipt using escape sequences

print("***** RECEIPT *****")
print("item\t\tPrice")
print("pen\t\t₹20")
print("notebook\t₹40")
print("pencil\t\t₹10")
print("\nTotal\t\t₹70")
# Out:
# ***** RECEIPT *****
# item		Price
# pen		₹20
# notebook	₹40
# pencil		₹10
#
# Total		₹70
