# %%
# program 2-This program takes the user's name, age and city and prints a greeting

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
city = input("Enter your city: ")
print(f"Hello {name} how are you, you are {age} years old and you live in {city}.")
# Out:
# Enter your name:  mishika
# Enter your age:  20
# Enter your city:  indore
# Hello mishika how are you, you are 20 years old and you live in indore.
