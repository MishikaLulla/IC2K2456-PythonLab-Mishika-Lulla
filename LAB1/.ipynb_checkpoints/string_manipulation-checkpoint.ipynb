# %%
# program5- this program demonstrates different string manipulation operations

# %%
full_name = input("enter your full name: ")
print("uppercase:", full_name.upper())
print("lowercase:", full_name.lower())
print("reversed:", full_name[::-1])
print("length:", len(full_name))
# Out:
# enter your full name:  mishika
# uppercase: MISHIKA
# lowercase: mishika
# reversed: akihsim
# length: 7
