# %%
def fibonacci(n):
    if n <= 1:
        return n

    return fibonacci(n - 1) + fibonacci(n - 2)


result = fibonacci(6)

print(result)
# Out:
# 8

# %% [markdown]
# time complexity: O(2ⁿ)
# space complexity: O(n)
#
# justify: each call creates two more recursive calls causing exponential growth while the maximum recursion depth is n
