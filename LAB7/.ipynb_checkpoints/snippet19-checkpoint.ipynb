# %%
def power(base, exp):
    if exp == 0:
        return 1

    return base * power(base, exp - 1)


result = power(2, 5)

print(result)
# Out:
# 32

# %% [markdown]
# time complexity: O(exp)
# space complexity: O(exp)
#
# justify: the exponent decreases by one in every recursive call so there are exp calls and the recursion stack grows to exp
