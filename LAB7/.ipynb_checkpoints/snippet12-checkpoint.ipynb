# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1

    return n * factorial(n - 1)


result = factorial(5)

print(result)
# Out:
# 120

# %% [markdown]
# time complexity: O(n)
# space complexity: O(n)
#
# justify: the function makes one recursive call for every value from n down to 1 and the recursive calls use linear stack space
